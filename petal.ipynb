# %%
import seaborn as sns
#load the dataset
df = sns.load_dataset('iris')
#calculate correlation
corr_matrix = df.corr('pearson', numeric_only=True) #kind of correlation->  ‘pearson’, ‘kendall’, ‘spearman’
#plot correlation
corr_matrix.style.background_gradient(cmap='coolwarm')
# 'RdBu_r', 'BrBG_r', & PuOr_r are other good diverging colormaps
# Out:
# <style type="text/css">
# #T_a41e3_row0_col0, #T_a41e3_row1_col1, #T_a41e3_row2_col2, #T_a41e3_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a41e3_row0_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_a41e3_row0_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_a41e3_row0_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_a41e3_row1_col0, #T_a41e3_row1_col2, #T_a41e3_row1_col3, #T_a41e3_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a41e3_row2_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_a41e3_row2_col3, #T_a41e3_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_a41e3_row3_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_a41e3_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a41e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a41e3_level0_col0" class="col_heading level0 col0" >sepal_length</th>
#       <th id="T_a41e3_level0_col1" class="col_heading level0 col1" >sepal_width</th>
#       <th id="T_a41e3_level0_col2" class="col_heading level0 col2" >petal_length</th>
#       <th id="T_a41e3_level0_col3" class="col_heading level0 col3" >petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a41e3_level0_row0" class="row_heading level0 row0" >sepal_length</th>
#       <td id="T_a41e3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a41e3_row0_col1" class="data row0 col1" >-0.117570</td>
#       <td id="T_a41e3_row0_col2" class="data row0 col2" >0.871754</td>
#       <td id="T_a41e3_row0_col3" class="data row0 col3" >0.817941</td>
#     </tr>
#     <tr>
#       <th id="T_a41e3_level0_row1" class="row_heading level0 row1" >sepal_width</th>
#       <td id="T_a41e3_row1_col0" class="data row1 col0" >-0.117570</td>
#       <td id="T_a41e3_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a41e3_row1_col2" class="data row1 col2" >-0.428440</td>
#       <td id="T_a41e3_row1_col3" class="data row1 col3" >-0.366126</td>
#     </tr>
#     <tr>
#       <th id="T_a41e3_level0_row2" class="row_heading level0 row2" >petal_length</th>
#       <td id="T_a41e3_row2_col0" class="data row2 col0" >0.871754</td>
#       <td id="T_a41e3_row2_col1" class="data row2 col1" >-0.428440</td>
#       <td id="T_a41e3_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a41e3_row2_col3" class="data row2 col3" >0.962865</td>
#     </tr>
#     <tr>
#       <th id="T_a41e3_level0_row3" class="row_heading level0 row3" >petal_width</th>
#       <td id="T_a41e3_row3_col0" class="data row3 col0" >0.817941</td>
#       <td id="T_a41e3_row3_col1" class="data row3 col1" >-0.366126</td>
#       <td id="T_a41e3_row3_col2" class="data row3 col2" >0.962865</td>
#       <td id="T_a41e3_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
